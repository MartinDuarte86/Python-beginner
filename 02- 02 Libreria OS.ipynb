# %% [markdown]
# ## Libreria os ##
#  os.path.join()
#
# Ejemplo
# + path ="C:/Users/maeduart/Google Drive/Github/Curso_Python_Udemy/datasets_Test"
# + filename="titanic/titanic3.csv"
# + fullpath= os.path.join(path,filename)

# %%
import pandas as pd 
import os

path ="C:/Users/maeduart/Google Drive/Github/02-Cursos/Curso_Python_Udemy/datasets_Test"
filename="titanic/titanic3.csv"

fullpath= os.path.join(path,filename)

data =  pd.read_csv(fullpath)
data.columns.values
